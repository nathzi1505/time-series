# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
PATH_df1 = "../03-Pandas-Visualization/df1.csv"
PATH_df2 = "../03-Pandas-Visualization/df2.csv"
PATH_df3 = "../03-Pandas-Visualization/df3.csv"

# %%
df1 = pd.read_csv(PATH_df1, index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv(PATH_df2)

# %%
df2.head()
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y

# %%
df1['A'].plot.hist()

# %%
df1['A'].plot.hist(bins=80, edgecolor='k').autoscale(enable=True, axis='both', tight=True)

# %%
df1['A'].plot.hist(grid=True)

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
df2.plot.barh(stacked=True)

# %%
df2.plot.line(y='a', figsize=(10, 4), lw=2)

# %%
df2.plot.line(y=['a', 'b', 'c'], figsize=(10, 4), lw=2)

# %%
df2.plot.area(stacked=False, alpha=0.4)

# %%
df1.plot.scatter(x='A', y='B')

# %%
df1.plot.scatter(x='A', y='B', c='C', cmap='coolwarm')

# %%
df1.plot.scatter(x='A', y='B', s=df1['C'] * 50, alpha=0.3)
# Out:
# /Users/nathzi1505/Desktop/Private/Online-Courses/Time-Series/Course_Notebooks/venv/lib/python3.6/site-packages/matplotlib/collections.py:886: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df1.plot.scatter(x='A', y='B', s=df1['C'] * 50, c='D', cmap='coolwarm', alpha=0.3)

# %%
df2.plot.box()

# %%
df2.plot.box(grid=True)

# %%
df2.plot.kde()

# %%
import numpy as np
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])

# %%
df.plot.scatter(x='a', y='b')

# %%
df.plot.hexbin(x='a', y='b', gridsize=25)
